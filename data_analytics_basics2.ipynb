# %% [markdown]
# <a href="https://colab.research.google.com/github/Manirathan-code/GDP-AND-PER-CAPITA/blob/main/data_analytics_basics2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "skdkjsosidjfoeij oisjdfojsf iofje"
print(s.count('j'))
print(s.count('j',1,9))
# Out:
# 6
# 1

# %%
#Replace - replace one string with another string
a = "Hello world"
print(a.replace("Hello","hey"))
# Out:
# hey world

# %%
p = "sadfsadhv flashman"
print(p.replace("sadfsadhv","bhanu"))
# Out:
# bhanu flashman

# %%
#chargung the case of setting
s = "leARNing pythON"
print(s.upper())
print(s.lower())
print(s.swapcase())
print(s.title())
print(s.capitalize())
# Out:
# LEARNING PYTHON
# learning python
# LEarnING PYTHon
# Learning Python
# Learning python

# %%
#check the types of characters present in string
print('mani123'.isalnum())
print('charan456'.isdigit())
print('mandeep789'.isalpha())
print('akshay123'.islower())
print('Bhagya'.istitle())
print(' '.isspace())
# Out:
# True
# False
# False
# True
# True
# True

# %%
# remove the duplicates
nums = [1,2,2,3,4,4]
print(list(set(nums)))
# Out:
# [1, 2, 3, 4]

# %%
# print the squares of the elements
nums = [1,2,3,4]
squares = [i*1 for i in nums]
print(squares)
# Out:
# [1, 2, 3, 4]

# %%
#Check the starting and ending of strings
a = "avarage"
print(a.startswith('av'))
print(a.endswith('db'))
# Out:
# True
# False

# %%
#strings formatting
x = "mani "
s = 5000
print("hi {0},Your salary is {1}".format(x,s))
# Out:
# hi mani ,Your salary is 5000

# %%
import datetime
date = datetime.datetime.now()
print(date)
print("{:%d-%m-%Y}".format(date))
# Out:
# 2026-03-07 10:26:57.403255
# 07-03-2026

# %%
a = ['ab','cd','ef']
a.reverse()
print(a)
# Out:
# ['ef', 'cd', 'ab']

# %%
a = ['ab','cd','ef']
result = [i[::-1]for i in a]
print(result)
# Out:
# ['ba', 'dc', 'fe']

# %%
import re
pattern = re.compile("ab")
count = 0
m = pattern.finditer("ababababaabbabaa")
for x in m:
  count+= 1
  print(x.start(),"--",x.end(),"--",x.group())
# Out:
# 0 -- 2 -- ab
# 2 -- 4 -- ab
# 4 -- 6 -- ab
# 6 -- 8 -- ab
# 9 -- 11 -- ab
# 12 -- 14 -- ab
